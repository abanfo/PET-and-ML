# %%
import pandas as pd
import os
#current working dir
print(os.getcwd())
# Out:
# /Users/abanfo/Documents/GitHub/PET-and-ML

# %% [markdown]
# ## Basic Data Exploration Adult dataset

# %%
# import data 
df = pd.read_csv(r'/Users/abanfo/Documents/GitHub/PET-and-ML/Dataset/adult.data',sep=',')
col_name=['age','workclass','fnlwgt','education','education-num','marital-astatus','occupation','relationship','race','sex','capital-gain','apital-loss','hours-per-week','native-country','class']
# add header to the dataframe
df.columns = col_name

# %%
print("size of the data set", df.size, "The shape of the data set", df.shape)
# Out:
# size of the data set 488400 The shape of the data set (32560, 15)

# %%
# check for missed value
df.isnull().any()
# Out:
# age                False
# workclass          False
# fnlwgt             False
# education          False
# education-num      False
# marital-astatus    False
# occupation         False
# relationship       False
# race               False
# sex                False
# capital-gain       False
# apital-loss        False
# hours-per-week     False
# native-country     False
# class              False
# dtype: bool

# %% [markdown]
# ## based on the above result there are no nan or empty entry on the dataset

# %%
df.shape
# Out:
# (32560, 15)

# %%
nan_rows = df[df['age'].notnull()]
nan_rows
# Out:
#        age          workclass  fnlwgt    education  education-num
# 0       50   Self-emp-not-inc   83311    Bachelors             13  \
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#            marital-astatus          occupation    relationship    race
# 0       Married-civ-spouse     Exec-managerial         Husband   White  \
# ...

# %%
df.loc[:, df.isnull().any()].columns
# Out:
# Index([], dtype='object')

# %%
df.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# education-num      0
# marital-astatus    0
# occupation         0
# relationship       0
# race               0
# sex                0
# capital-gain       0
# apital-loss        0
# hours-per-week     0
# native-country     0
# class              0
# dtype: int64

# %% [markdown]
# ## Basic Data Exploration Diabetes dataset

# %%
df = pd.read_csv(r'/Users/abanfo/Documents/GitHub/PET-and-ML/Dataset/adult.data',sep=',')
